# %%
sent=["The world is a better place",
      "Marvel series is my favourite movie",
      "I like DC movies",
      "the cat is eating the food",
      "Tom and Jerry is my favourite movie",
      "Python is my favourite programming language"
      ]

# %%
from keras.layers import TextVectorization

# %%
voc_size=10000

# %%
vectorizer = TextVectorization(
                    max_tokens=voc_size,
                    output_mode='int',
                    output_sequence_length=10)
vectorizer.adapt(sent)
encoded=vectorizer(sent)
encoded
# Out:
# <tf.Tensor: shape=(6, 10), dtype=int64, numpy=
# array([[ 3,  7,  2, 25, 23, 12,  0,  0,  0,  0],
#        [14,  9,  2,  4,  5,  6,  0,  0,  0,  0],
#        [18, 15, 21, 13,  0,  0,  0,  0,  0,  0],
#        [ 3, 22,  2, 20,  3, 19,  0,  0,  0,  0],
#        [ 8, 24, 17,  2,  4,  5,  6,  0,  0,  0],
#        [10,  2,  4,  5, 11, 16,  0,  0,  0,  0]])>

# %%
from keras.layers import Embedding
from keras.models import Sequential
from keras.preprocessing.sequence import pad_sequences

# %%
dim = 10          # Embedding vector size
voc_sizvoc_size = len(vectorizer.get_vocabulary())  # automatically includes padding token
max_len = 10      # Padded sequence length

model = Sequential()
model.add(Embedding(
    input_dim=voc_size, 
    output_dim=dim, 
    input_length=max_len
))

model.compile('adam','mse')
# Out:
# c:\Users\PC\anaconda3\envs\tf_env\lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
print(model.predict(encoded))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# [[[ 0.01751233 -0.00765514 -0.00217856  0.00476421  0.03657613
#    -0.01499297 -0.01323541  0.01264936  0.00646339  0.01609305]
#   [-0.01179042  0.03191488  0.04499865 -0.00730266 -0.00930651
#    -0.04608729 -0.0002362   0.01494173 -0.01361535 -0.04318599]
#   [-0.03062254  0.04831785 -0.0190981   0.04924841  0.03525202
#    -0.02117436 -0.03054297 -0.03371714  0.03038189  0.04377227]
#   [ 0.0464913   0.04460896  0.01538933  0.01411741  0.01948352
#     0.0402725   0.04034093 -0.04312643  0.01451678 -0.04528177]
#   [ 0.0045705  -0.01337113  0.00578488 -0.03114974  0.01510486
#     0.0091337  -0.0083523  -0.00669801 -0.04927972 -0.01796384]
#   [ 0.04041599 -0.02414017  0.03256681  0.02722367 -0.01278657
#     0.00195136  0.04935556 -0.04118656 -0.04147366 -0.01064507]
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]]
#
#  [[ 0.01986251  0.04343775 -0.01920286 -0.02581915 -0.01324151
#     0.01422084  0.01259091  0.00170247  0.03101837  0.01894129]
#   [ 0.04416983 -0.02249196 -0.00662414 -0.00274966 -0.04219332
#     0.01607661 -0.04874798  0.0436714   0.04248801 -0.01822805]
#   [-0.03062254  0.04831785 -0.0190981   0.04924841  0.03525202
#    -0.02117436 -0.03054297 -0.03371714  0.03038189  0.04377227]
#   [-0.00313658 -0.00900237 -0.00248764  0.0005703   0.04965112
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]]
#
#  [[ 0.02807323  0.01256648  0.03121641 -0.02434972 -0.03688686
#     0.04143169 -0.01414199 -0.04893949 -0.04274146  0.03001935]
#   [-0.01679636  0.00136247  0.01939643  0.02978538  0.04758037
#    -0.03088766  0.04324888 -0.00095598  0.03121806  0.00019833]
#   [ 0.04695939 -0.04966718  0.04153587  0.02938925 -0.01534859
#    -0.04127746  0.01660505 -0.02933023 -0.03496711 -0.00120385]
#   [-0.03062254  0.04831785 -0.0190981   0.04924841  0.03525202
#    -0.02117436 -0.03054297 -0.03371714  0.03038189  0.04377227]
#   [-0.00313658 -0.00900237 -0.00248764  0.0005703   0.04965112
#     0.02510002  0.04034491  0.00645842 -0.00035206 -0.03021514]
#   [-0.00649291 -0.04776995  0.04046952 -0.00607352  0.00022532
#    -0.00254748 -0.01221309 -0.04676603 -0.01646044  0.03326149]
#   [ 0.03576523 -0.00593243 -0.02520913 -0.04123561  0.00246935
#     0.03986175  0.00688883 -0.04122255 -0.00225738 -0.00781684]
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]]
#
#  [[-0.00609666  0.02770976  0.03730911  0.002459   -0.02357376
#    -0.01752198  0.03726241  0.01279502  0.0055526   0.01629558]
#   [-0.03062254  0.04831785 -0.0190981   0.04924841  0.03525202
#    -0.02117436 -0.03054297 -0.03371714  0.03038189  0.04377227]
#   [-0.00313658 -0.00900237 -0.00248764  0.0005703   0.04965112
#     0.02510002  0.04034491  0.00645842 -0.00035206 -0.03021514]
#   [-0.00649291 -0.04776995  0.04046952 -0.00607352  0.00022532
#    -0.00254748 -0.01221309 -0.04676603 -0.01646044  0.03326149]
#   [ 0.01938501 -0.01117282  0.04531519 -0.03925241  0.02147407
#    -0.04045147  0.01330983  0.00216205 -0.03022251 -0.04208542]
#   [ 0.03689683  0.04495532  0.00292915 -0.02887801 -0.04715365
#     0.01467333  0.04860343 -0.04298021  0.04987952  0.01096982]
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]
#   [-0.04391685  0.01790998 -0.0059059   0.02393239 -0.04142557
#     0.01662331  0.00452167 -0.0294242  -0.00920073 -0.02584254]]]
